# %%
#open CV is use image processing 
import cv2
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread("D:/Project 16/ProjrctNUL/images (2).png")

# %%
plt.imshow(img1)

# %%
#Airthmetic operation
img2 = cv2.imread("D:/Project 16/ProjrctNUL/download.jpg")

# %%
result = img1 +img2

# %%
plt.imshow(result)

# %%
result2 = img1 - img2

# %%
plt.imshow(result2)

# %%
result2 = img1 * img2

# %%
plt.imshow(result2)

# %%
result3 = img1 / img2
# Out:
# C:\Users\pkuma\AppData\Local\Temp\ipykernel_20332\4082502265.py:1: RuntimeWarning: divide by zero encountered in divide
#   result3 = img1 / img2
# C:\Users\pkuma\AppData\Local\Temp\ipykernel_20332\4082502265.py:1: RuntimeWarning: invalid value encountered in divide
#   result3 = img1 / img2

# %%
plt.imshow(result3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..225.0].

# %%
img4 = cv2.imread("D:/Project 16/ProjrctNUL/images (4).png")

# %%
plt.imshow(img4)

# %%
img = cv2.cvtColor(img4,cv2.COLOR_BGR2HSV)
figure_size = 7
result5 = cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize = (11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img ,cv2.COLOR_HSV2RGB)),plt.title("original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result5 ,cv2.COLOR_HSV2RGB)),plt.title("Blurred")
plt.xticks([]),plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img6 = cv2.imread("D:/Project 16/ProjrctNUL/images (1).png")

# %%
(height , width) = img1.shape[0:2]
zoom = cv2.resize(img1,None,fx = 1.5 , fy = 1.5 , interpolation = cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom = cv2.resize(img1,(int(width*2),int(height*2)) , interpolation = cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom = cv2.resize(img1,(int(width/2),int(height/5)) , interpolation = cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
m = cv2.getRotationMatrix2D((width/2 , height/2),30,1)
rotate = cv2.warpAffine(img1 ,m,( height , width))
plt.imshow(rotate)

# %%
import numpy as np

# %%
m = np.float32([[1,0 ,50],[0,1,100]])
dst = cv2.warpAffine(img1,m , (height,width))
plt.imshow(dst)
